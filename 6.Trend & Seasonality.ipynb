# %%
import pandas as pd
import numpy as np
from matplotlib.pylab import plt
# %matplotlib inline

import statsmodels

# %%
print('statsmodels ', statsmodels.__version__)
print('numpy ', np.__version__)
print('pandas ', pd.__version__)
# Out:
# statsmodels  0.8.0
# numpy  1.13.3
# pandas  0.20.3

# %%
air_passengers = pd.read_csv('data/AirPassengers.csv', header=0, parse_dates=[0],\
                             names=['Month', 'Passengers'], index_col=0)
air_passengers.head()
# Out:
#             Passengers
# Month
# 1949-01-01         112
# 1949-02-01         118
# 1949-03-01         132
# 1949-04-01         129
# 1949-05-01         121

# %%
air_passengers['1949-01-5':'1949-3-28']
# Out:
#             Passengers
# Month
# 1949-02-01         118
# 1949-03-01         132

# %%
air_passengers.plot()

# %%
air_passengers['1950'].plot(kind='bar')

# %% [markdown]
# ### First thing we look at for a time series when we want to use common analysis techniques:
#
# ### Is it stationary: mean, variance, autocovariance do not depend on time

# %%
# Moving average using rolling function
air_passengers.rolling(window=60).mean().plot()

# %%
air_passengers.rolling(window=60).var().plot()

# %%
from statsmodels.tsa.stattools import acf
air_passengers.rolling(window=60).acf().plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-ec5a4af55eb4> in <module>()
#       1 from statsmodels.tsa.stattools import acf
# ----> 2 air_passengers.rolling(window=60).acf().plot()
#
# ~/DataScience/anaconda3/lib/python3.6/site-packages/pandas/core/window.py in __getattr__(self, attr)
#     177
#     178         raise AttributeError("%r object has no attribute %r" %
# --> 179                              (type(self).__name__, attr))
#     180
#     181     def _dir_additions(self):
#
# AttributeError: 'Rolling' object has no attribute 'acf'
